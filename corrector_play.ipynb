# %%
import sys

# %%
sys.path.append('/Users/haozhi/Codes/Mic_Hackathon_2025/')
sys.path.append('/Users/haozhi/Codes/Mic_Hackathon_2025/RL_STEM/result/SR/')

# %%
from RL_STEM import *

# %%
# !{sys.executable} result/SR/sr_sindy_v2_A1_complete.py
# Out:
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/pysindy/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound
# Filtering y outside [0.328, 87.294]
# Kept 515 / 527 samples
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#
# Test R² = 0.710297
#
# Generic SINDy print:
# ...

# %%
# Action A1 to C1 coupling
# !{sys.executable} result/SR/sr_sindy_v2_A1_complete_C1.py
# Out:
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/pysindy/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound
# Filtering y outside [-7.330, 9.306]
# Kept 495 / 527 samples
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# ...

# %%
# Action C1 to A1 coupling
# !{sys.executable} result/SR/sr_sindy_v2_C1_complete.py
# Out:
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/pysindy/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound
# Filtering |strength| < 1
# Kept 606 / 1913 samples
# Filtering |C1| > 100.0
# Kept 589 / 606 samples
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/miniconda3/envs/corrector_play/lib/python3.10/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# ...

# %%
# Run GUI for human-interactions with the simulator
# The results of symbolic regression is already explictly written in CorrectorPlayEnv_v4.py
# If wanted, the form of those fitting could also be adjusted 
# !{sys.executable} Play_UI_v4.py

# %%
# Reinforcement model training with PPO
# !{sys.executable} train_ppo_v4.py
# Out:
# ...
# PPO Training for CorrectorPlayEnv v3
# ...
# Experiment directory: ./logs/ppo_corrector_v3_20251218_215909
# wandb: Currently logged in as: shzmic (shzmic-lbl) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.23.1
# wandb: Run data is saved locally in /Users/haozhi/Data/Mic_Hackathon2025/RL_STEM/wandb/run-20251218_215909-cylaz9i6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ppo_corrector_v3_20251218_215909
# wandb: ⭐️ View project at https://wandb.ai/shzmic-lbl/corrector-ppo-v3
# wandb: 🚀 View run at https://wandb.ai/shzmic-lbl/corrector-ppo-v3/runs/cylaz9i6
# Wandb run: https://wandb.ai/shzmic-lbl/corrector-ppo-v3/runs/cylaz9i6
# Creating 64 parallel environments...
#
# Environment Configuration:
#   max_steps: 200
#   goal_threshold: 50.0
#   max_deviation: 5000.0
#   obs_clip: 10000.0
# ...

# %%
# Evaluate trained model
# Pull model index from the logs and repalce ppo_corrector_v3_20251218_184558 with it
# !{sys.executable} evaluate_v4.py \
  --model-path ./logs/ppo_corrector_v3_20251218_150017/final_model \
  --compare-random \
  --plot \
  --n-episodes 5 \
  --max-steps 100
# Out:
# Loaded model from: ./logs/ppo_corrector_v3_20251218_150017/final_model
#
# ...
# Evaluating TRAINED model (deterministic)
# ...
# Episode   1: TIMEOUT | Reward: -1004.81 | Length:    6 | Init Dev:  5587.12 | Final Dev: 145386.31
# Episode   2: TIMEOUT | Reward: -1008.32 | Length:   10 | Init Dev:  3202.13 | Final Dev: 145288.94
# Episode   3: TIMEOUT | Reward: -1004.85 | Length:    6 | Init Dev:  4502.96 | Final Dev: 123614.79
# Episode   4: TIMEOUT | Reward: -1004.80 | Length:    6 | Init Dev:  6606.66 | Final Dev: 138088.82
# Episode   5: TIMEOUT | Reward:   -92.66 | Length:  100 | Init Dev:  3404.29 | Final Dev:  7879.83
#
# ...
# Evaluating RANDOM policy
# ...
# Episode   1: TIMEOUT | Reward: -1005.00 | Length:    6 | Init Dev:  5587.12 | Final Dev: 152813.07
# Episode   2: TIMEOUT | Reward: -1048.17 | Length:   54 | Init Dev:  3202.13 | Final Dev: 297713.48
# Episode   3: TIMEOUT | Reward: -1011.65 | Length:   16 | Init Dev:  4502.96 | Final Dev: 204957.78
# ...
